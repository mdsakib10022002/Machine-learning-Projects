# %% [markdown]
# ### This model basically based on the linear regression algorithm, we use data to predict the house price
# ### on the basis of the training data that we use for training the linear regression model

# %% [markdown]
# # House price Prediction model

# %% [markdown]
# ### Step 1: We import some importenet libraries for calculation that will use in model

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Then we Give some data to the model training

# %%
x_train = np.array([1.0,2.0,3.0,4.0,6.0])
y_train = np.array([300.0,500.0,700.0,900.0,1100.0])
print(f"X_train {x_train}")
print(f"y_train {y_train}")
# Out:
# X_train [1. 2. 3. 4. 6.]
# y_train [ 300.  500.  700.  900. 1100.]

# %%
# select  the training examples m
m = x_train.shape[0]
m
# Out:
# 5

# %%
# plot the data 
plt.scatter(x_train, y_train, marker='x', color='r')
plt.title("Linear regression model")
plt.xlabel('x_train')
plt.ylabel("y_tarin");

# %% [markdown]
# ## Model function
# * As described in lecture, the model function for linear regression (which is a function that maps from x to y) is represented as
#
# ##                                     𝑓𝑤,𝑏(𝑥(𝑖))=𝑤𝑥(𝑖)+𝑏(1)
#
# * The formula above is how you can represent straight lines - different values of  𝑤and  𝑏
# * give you different straight lines on the plot.
#
#
#
#
#
# * Let's try to get a better intuition for this through the code blocks below. Let's start with  𝑤=100
# * and  𝑏=100
#  .
#
# ## Note: You can come back to this cell to adjust the model's w and b parameters

# %% [markdown]
# ## Compute the function

# %%
def compute_model(x,w,b):
    m = x_train.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] 
        = x[i]*w + b
    return f_wb

# %%
# w = 100
# b = 100

# %%
result = compute_model(x_train, w, b)
plt.plot(x_train, result, color='r', label="Our prediction")
plt.scatter(x_train, y_train, marker='x', color='b', label='Actual_values')
plt.title('Prediction')
plt.ylabel("Price")
plt.xlabel("Size in sqrf")
plt.legend()
plt.show()

# %%
# let assume w and b for different values
w=200
b = 100

# %% [markdown]
# ### Now we have a model to predict

# %%
x_i = float(input("Enter House size in float: "))
cost_for_1200 = w*x_i+b
cost_for_1200
# Out:
# Enter House size in float:  2.8
